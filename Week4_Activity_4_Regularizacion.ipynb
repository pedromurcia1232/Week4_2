# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromurcia1232/Week4_2/blob/main/Week4_Activity_4_Regularizacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning – Semana 4
# ## Regularización en Redes Neuronales
# Comparación entre un modelo base y un modelo con regularización (L2 y Dropout) para evidenciar overfitting y mejora en generalización.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dataset de ejemplo
# Se utiliza un dataset sintético de clasificación binaria para observar overfitting.

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=1000, noise=0.2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Modelo base (sin regularización)

# %%
model_base = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(2,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
model_base.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_base = model_base.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose=0)

# %% [markdown]
# ## Modelo con regularización (L2 + Dropout)

# %%
from tensorflow.keras.regularizers import l2
model_reg = keras.Sequential([
    layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01), input_shape=(2,)),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01)),
    layers.Dense(1, activation='sigmoid')
])
model_reg.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_reg = model_reg.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), verbose=0)

# %% [markdown]
# ## Comparación de resultados

# %%
plt.figure()
plt.plot(history_base.history['val_loss'], label='Base')
plt.plot(history_reg.history['val_loss'], label='Regularizado')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusiones
# - El modelo base presenta mayor overfitting.
# - La regularización estabiliza el aprendizaje y mejora la generalización.
# - Dropout y L2 reducen dependencia excesiva de pesos individuales.
